# %% [markdown]
# <a href="https://colab.research.google.com/github/fmuranda/Machine_Learning-/blob/main/Tensor_data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
#@title Integer data type tensor
int_tensor = torch.tensor([1,2,3,4,5],dtype=torch.int8)
int_tensor.dtype
# Out:
# torch.int8

# %%
#@title Float data type tensor
float_tensor = torch.tensor([6,7,8,9,10],dtype=torch.float32)
float_tensor.dtype
# Out:
# torch.float32

# %%
#@title Short data type tensor
short_tensor = torch.tensor([11,12,13,14,15],dtype=torch.short)
short_tensor.dtype
# Out:
# torch.int16

# %%
#@title Casting a tensor to a new data type (1st way)
last_tensor = short_tensor.to(dtype=torch.int8)
last_tensor.dtype
# Out:
# torch.int8
