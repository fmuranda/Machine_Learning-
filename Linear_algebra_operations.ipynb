# %% [markdown]
# <a href="https://colab.research.google.com/github/fmuranda/Machine_Learning-/blob/main/Linear_algebra_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
#@title Compute the dot product (scalar) of two Id tensors
first_tensor = torch.tensor([1,2,3])
second_tensor = torch.tensor([4,5,6])

dot_product = torch.matmul(first_tensor, second_tensor)
dot_product
# Out:
# tensor(32)

# %%
#@title Compute the matrix-matrix product (2D tensor) of two 2d tensors
first_2d_tensor = torch.tensor([[1,2,3],[-1,-2,-3]])
second_2d_tensor = torch.tensor([[-1,-2],[4,5],[4,5]])

result_2d_tensor = torch.matmul(first_2d_tensor, second_2d_tensor)
result_2d_tensor
# Out:
# tensor([[ 19,  23],
#         [-19, -23]])

# %%
#@title Compute the matrix product of 5 2d tensors
first_ten = torch.randn(2,3)
second_ten = torch.randn(3,4)
third_ten = torch.randn(4,5)
fourth_ten = torch.randn(5,6)
fifth_ten = torch.randn(6,7)
torch.linalg.multi_dot([first_ten, second_ten, third_ten, fourth_ten, fifth_ten])
# Out:
# tensor([[-55.9551,  -1.5012,  23.7368, -42.6842, -71.4189,  30.6156,  -7.9198],
#         [ -9.7142,   3.0310,  -1.0573,  -5.7856, -17.3081,   2.1782,   6.9135]])

# %%
#@title Computing eigenvalues and eigenvectors
#create a 3x3 square matrix
A = torch.randn(4,4)

# print the above created matrix
print("Matrix:",A)

#print the above created matrix
print ("Matrix", A)

# compute the Eigen values and vectors of the matrix
eigenvalues, eigenvectors = torch.linalg.eigh(A)

print("Eigen Values:", eigenvalues)
print("Eigen Vectors:", eigenvectors)
# Out:
# Matrix: tensor([[-1.3098,  0.2030, -0.2780,  0.0858],
#         [-0.3808, -2.4500,  0.2708,  0.4056],
#         [-0.5621, -2.0507, -0.9377, -1.3963],
#         [ 0.8555, -0.8140, -0.5199, -1.3931]])
# Matrix tensor([[-1.3098,  0.2030, -0.2780,  0.0858],
#         [-0.3808, -2.4500,  0.2708,  0.4056],
#         [-0.5621, -2.0507, -0.9377, -1.3963],
#         [ 0.8555, -0.8140, -0.5199, -1.3931]])
# Eigen Values: tensor([-4.2499, -2.1957, -0.1791,  0.5342])
# Eigen Vectors: tensor([[-0.1225, -0.7364,  0.6395, -0.1835],
#         [-0.7777, -0.0413, -0.3465, -0.5228],
#         [-0.5470, -0.1218, -0.0074,  0.8282],
#         [-0.2845,  0.6642,  0.6862, -0.0841]])
