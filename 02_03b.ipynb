# %% [markdown]
# <a href="https://colab.research.google.com/github/fmuranda/Machine_Learning-/blob/main/02_03b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %%
numbers_df = DataFrame(np.arange(0,90,3).reshape(10,3), index = ['row 1','row 2','row 3','row 4','row 5','row 6','row 7','row 8','row 9','row 10'],columns=['column 1','column 2','column 3'])
numbers_df
# Out:
#         column 1  column 2  column 3
# row 1          0         3         6
# row 2          9        12        15
# row 3         18        21        24
# row 4         27        30        33
# row 5         36        39        42
# row 6         45        48        51
# row 7         54        57        60
# row 8         63        66        69
# row 9         72        75        78
# row 10        81        84        87
